# %%
import polars as pl
from modulos import *
from pathlib import Path
from modulos_resumen import *

RUTA_BASE = str(Path(__file__).resolve().parent)


df_lda = pl.read_parquet( f'{RUTA_BASE}/ejecucion/lda.parquet')
df_nmf = pl.read_parquet( f'{RUTA_BASE}/ejecucion/nmf.parquet')
df_bert = pl.read_parquet( f'{RUTA_BASE}/ejecucion/crudo_bert.parquet')




columnas_diversidad =  {
    1 : ['subconjunto','columna','numero_topicos','num_topico',
         'hiperparametros','model_id','palabra','coherencia_umass'],
    2 : ['subconjunto','columna','numero_topicos','hiperparametros',
         'model_id','palabra' ],
    3 : ['subconjunto','columna','numero_topicos','hiperparametros',
         'model_id' ],
    4 : ['subconjunto','columna','numero_topicos','hiperparametros',
         'model_id' ,'diversidad','coherencia_umass']
 }

def calcular_y_graficar(df_modelo, nombre_modelo):
    metricas = calcular_metricas(df_modelo, nombre_modelo, columnas_diversidad)
    df_modelo = metricas['df_modelo'] 
    df_metricas = metricas['df_metricas']
    dict_hiperparametros = metricas['dict_hiperparametros']

    prom_coherencia = metricas['prom_coherencia']            
    prom_diversidad = metricas['prom_diversidad']


        
    plot_pareto_frontier(df_metricas, 
                        nombre_modelo, 
                        f'Modelos {nombre_modelo}: Coherencia (UMass) vs Diversidad',
                        '',
                        prom_coherencia, 
                        prom_diversidad, 
                        f'{nombre_modelo}_sp_todos', 
                        'Columnas',
                        posicion_coherencia='bottom right',
                        posicion_diversidad='bottom right')

    dict_criterios = {
        1:'porc_del_dominio',
        2:'del_dominio',
        3:'diversidad',
        4:'coherencia_umass'
    }
    posicion_anotaciones ={
        1:['bottom right','bottom right'],
        2:['bottom right','bottom right'],
        3:['bottom right','bottom right'],
        4:['bottom right','top right']
    }
    subtitulos = {
        1:'20 mejores resultados según porcentaje de palabras en dominio',
        2:'20 mejores resultados según coincidencias en dominio',
        3:'20 mejores resultados según diversidad',
        4:'20 mejores resultados según Coherencia Umass'
    }
    dict_mejores = {}
    dict_mejores[1] = obtener_del_dominio(df_modelo, df_metricas, 20, dict_criterios[1])
    dict_mejores[1].write_excel(f'{RUTA_BASE}/graficos/{nombre_modelo}_mejores_porc.xlsx')
    dict_mejores[2] = obtener_del_dominio(df_modelo, df_metricas, 20, dict_criterios[2])
    dict_mejores[2].write_excel(f'{RUTA_BASE}/graficos/{nombre_modelo}_mejores_dominio.xlsx')
    dict_mejores[3] = obtener_del_dominio(df_modelo, df_metricas, 20, dict_criterios[3])
    dict_mejores[3].write_excel(f'{RUTA_BASE}/graficos/{nombre_modelo}_mejores_diversidad.xlsx')
    dict_mejores[4] = obtener_del_dominio(df_modelo, df_metricas, 20, dict_criterios[4])
    dict_mejores[4].write_excel(f'{RUTA_BASE}/graficos/{nombre_modelo}_mejores_umass.xlsx')

    print('='*50)
    print('='*50)

    for i in dict_criterios.keys():

        print(dict_criterios[i].upper())
        print('.'*50)
        df_ = dict_mejores[i].head(1)
        valor = {c:df_[c][0] for c in dict_mejores[i].columns}
        for v in valor.items():
            print(v)
        plot_pareto_frontier(dict_mejores[i], 
                            nombre_modelo, 
                            f'{nombre_modelo}: Coherencia UMass vs Diversidad',
                            subtitulos[i],
                            prom_coherencia, 
                            prom_diversidad, 
                            f'{nombre_modelo}_mejores_{dict_criterios[i]}',
                            'Columnas',
                            posicion_coherencia=posicion_anotaciones[i][0], 
                            posicion_diversidad=posicion_anotaciones[i][1])

        df_nube, coherencia, diversidad = crea_df_para_nube(df_modelo, 
                                                            df_metricas, 
                                                            valor['model_id'],
                                                            valor['subconjunto'],
                                                            valor['columna'],
                                                            valor['numero_topicos'])
        generate_wordcloud(df_nube, "palabra", f'{nombre_modelo}_wc_3_denuncia_todos')
        print('Coherencia',coherencia)
        print('Diversidad', diversidad)

        imprime_palabras(df_nube)
        print('='*50)
        print('='*50)
        print(' ')
        print('='*50)
        print('='*50)


    return df_modelo, df_metricas, dict_hiperparametros

# LDA ----------------------------------------------
nombre_modelo = 'LDA'
df_modelo, df_metricas, _ = calcular_y_graficar(df_lda, nombre_modelo)

# NMF ----------------------------------------------
nombre_modelo = 'NMF'
df_modelo, df_metricas, dict_hiperparametros = calcular_y_graficar(df_nmf, nombre_modelo)
print(dict_hiperparametros)

# BERT ----------------------------------------------
nombre_modelo = 'BERT'
df_modelo, df_metricas, dict_hiperparametros = calcular_y_graficar(df_bert, nombre_modelo)
print(dict_hiperparametros)
# Out:
# ==================================================
# ==================================================
# PORC_DEL_DOMINIO
# ..................................................
# ('subconjunto', 'todos')
# ('columna', 'dictamen_dom')
# ('numero_topicos', 3)
# ('hiperparametros', '')
# ('model_id', 'todos_dictamen_dom_K3_')
# ('diversidad', 0.6666666666666666)
# ('coherencia_umass', -1.5981183872502374)
# ('del_dominio', 9)
# ('palabras_unicas', 25)
# ('porc_del_dominio', 0.36)
# Coherencia -1.5981183872502374
# Diversidad 0.6666666666666666
# 0 pago, operacion, coercitivo, cuenta, importe, transaccion, anticipado, tarjeta, segun, pagar
# 1 pago, coercitivo, regional, operacion, cuenta, cargo, opcion, confirmar, telf, urb
# 2 telf, firma, fax, digital, num, perentorio, modificacion, dicta, desistimiento, modificatoria
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# DEL_DOMINIO
# ..................................................
# ('subconjunto', 'comisión_lim')
# ('columna', 'dictamen_dom')
# ('numero_topicos', 30)
# ('hiperparametros', '')
# ('model_id', 'comisión_lim_dictamen_dom_K30_')
# ('diversidad', 0.3933333333333333)
# ('coherencia_umass', -1.9479290358927766)
# ('del_dominio', 16)
# ('palabras_unicas', 174)
# ('porc_del_dominio', 0.09195402298850575)
# Coherencia -1.9479290358927766
# Diversidad 0.3933333333333333
# 0 correo, electronico, infundado, tarjeta, verifico, error, enviar, credito, oportuno, mencionado
# 1 pago, regional, anexo, opcion, coercitivo, numero, pagar, cuenta, cargo, presidente
# 2 conceder, suspensivo, separar, cuaderno, tramitado, tramitando, dicta, treinta, modificatoria, perentorio
# 3 interes, archivo, conclusion, anticipado, desistimiento, entranase, iniciacion, suscitado, continuar, finalizar
# 4 interes, urb, santo, libertad, digitalmente, arquimed, firmar, miembro, modo, regional
# 5 operacion, cargo, cuenta, importe, cuestionado, tarjeta, ahorro, titularidad, sol, ocurrir
# 6 cargar, infundado, tarjeta, credito, cobertura, pasaje, signature, inciso, gasto, anterioridad
# 7 finanzas, interamericano, credito, pago, regional, improcedente, virtual, transaccion, considerativo, tarjeta
# 8 credito, tarjeta, operacion, deuda, riesgo, cargo, importe, fax, banca, superintendencia
# 9 cuestionado, apruebar, fax, posterior, demanda, esquina, improcedente, whatsapp, ocurrir, material
# 10 desistimiento, aceptar, archivo, finalizar, interesado, fax, interes, continuar, apersonado, plano
# 11 confirmar, coercitivo, cuestionado, pago, fax, cuenta, accesorio, especificamente, comunicar, posterior
# 12 mgtr, organizacion, celular, fijo, miembro, contener, singular, sesion, acta, voto
# 13 carta, coercitivo, fax, inicialmente, notarial, num, pago, setimo, allano, pese
# 14 pago, prestamo, solicitado, denegar, seguro, hipotecario, urb, tasa, cuenta, interes
# 15 firma, digital, certificado, eficacia, validez, organizacion, junin, regional, firmado, formato
# 16 confirmar, prestamo, accesorio, indebidamente, personal, levantar, ordenado, cuestionado, revocar, principal
# 17 deuda, reprogramacion, centro, informe, abstencion, espontaneo, embargo, riesgo, anular, cancelar
# 18 operacion, cuenta, cargo, coercitivo, importe, realizacion, titularidad, rebajado, cancelar, espontaneo
# 19 seguro, cuenta, fax, infundado, compania, num, improcedente, reaseguro, poliza, prestamo
# 20 reclamo, pese, adecuadamente, respuesta, adecuado, reportar, cuota, movil, cancelar, cts
# 21 jiron, principal, regional, amazona, opcion, liquidacion, organizacion, interes, segun, emitido
# 22 num, fax, modificase, modificatoria, modificacion, dicta, perentorio, decimo, reclamo, infundado
# 23 credito, seguro, confirmar, cuenta, impugnable, archivar, tarjeta, ocurrir, demanda, titularidad
# 24 conciliacion, desistimiento, silencio, extrajudicial, transaccion, mgtr, fondo, adoptado, positivo, archivo
# 25 regional, adscrito, presidente, distrito, pago, urb, espontaneo, telef, urbanizacion, forzoso
# 26 cargo, operacion, pago, reconocimiento, importe, transaccion, num, cuenta, titularidad, interes
# 27 interes, celebrar, fax, continuacion, archivo, finalizar, justifiquen, aceptar, cancelar, hipotecario
# 28 anticipado, conclusion, interes, promover, continuar, llegar, suscitado, iniciacion, entranase, finalizar
# 29 coercitivo, pago, publicacion, suspensivo, conceder, comunicacion, pagar, entrar, cuaderno, separar
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# DIVERSIDAD
# ..................................................
# ('subconjunto', 'comisión_lim')
# ('columna', 'dictamen')
# ('numero_topicos', 3)
# ('hiperparametros', '')
# ('model_id', 'comisión_lim_dictamen_K3_')
# ('diversidad', 0.9333333333333333)
# ('coherencia_umass', -0.698823171289431)
# ('del_dominio', 2)
# ('palabras_unicas', 29)
# ('porc_del_dominio', 0.06896551724137931)
# Coherencia -0.698823171289431
# Diversidad 0.9333333333333333
# 0 regional, oficina, emitir, telefono, reglamento, firma, resolutivo, funcion, parrafo, digital
# 1 sancion, conforme, cumplir, mayor, cumplimiento, mandato, registro, proveedor, coercitivo, resolutivo
# 2 interponer, firme, impugnativo, fax, presunto, interes, num, interpuesto, oficio, disposicion
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# COHERENCIA_UMASS
# ..................................................
# ('subconjunto', 'orps_lim')
# ('columna', 'dictamen')
# ('numero_topicos', 8)
# ('hiperparametros', '')
# ('model_id', 'orps_lim_dictamen_K8_')
# ('diversidad', 0.45)
# ('coherencia_umass', -0.5670528082141346)
# ('del_dominio', 8)
# ('palabras_unicas', 54)
# ('porc_del_dominio', 0.14814814814814814)
# Coherencia -0.5670528082141346
# Diversidad 0.45
# 0 coercitivo, costo, mandato, cuenta, apercibimiento, parrafo, precedente, amonestacion, uit, tributario
# 1 regional, oficina, anticipado, denuncia, desistimiento, declarar, conclusion, sancionador, cualquiera, opcion
# 2 cuenta, operacion, ahorro, importe, presunto, literal, realizar, presidencia, consejo, ministro
# 3 acuerdo, firma, junin, digital, conciliatorio, tributario, criterio, opcion, electronico, forma
# 4 coercitivo, costo, uit, tributario, operacion, apercibimiento, monto, correctiva, mandato, orden
# 5 cum, oficina, regional, seleccionar, costo, cualquiera, perjuicio, numero, monto, comision
# 6 monto, cum, numero, costo, seleccionar, uit, pagar, instancia, apercibimiento, efecto
# 7 tarjeta, credito, operacion, realizar, cargo, importe, coercitivo, seguro, incurrir, deuda
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# ==================================================
# ==================================================
# PORC_DEL_DOMINIO
# ..................................................
# ('subconjunto', 'todos')
# ('columna', 'contenido_dom')
# ('numero_topicos', 3)
# ('hiperparametros', '2')
# ('model_id', 'todos_contenido_dom_K3_2')
# ('diversidad', 0.8)
# ('coherencia_umass', -0.5329937549755456)
# ('del_dominio', 10)
# ('palabras_unicas', 27)
# ('porc_del_dominio', 0.37037037037037035)
# Coherencia -0.5329937549755456
# Diversidad 0.8
# 0 pago, reconocimiento, operacion, coercitivo, presidencia, cuenta, reparadora, allanar, junin, cargo
# 1 operacion, tarjeta, credito, cuenta, telf, fax, pago, reclamo, regional, usuario
# 2 anticipado, conclusion, desistimiento, conciliacion, promover, conciliatorio, extrajudicial, continuar, interes, transaccion
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# DEL_DOMINIO
# ..................................................
# ('subconjunto', 'orps_lim')
# ('columna', 'dictamen_dom')
# ('numero_topicos', 35)
# ('hiperparametros', '6')
# ('model_id', 'orps_lim_dictamen_dom_K35_6')
# ('diversidad', 0.46285714285714286)
# ('coherencia_umass', -2.621025701489073)
# ('del_dominio', 17)
# ('palabras_unicas', 222)
# ('porc_del_dominio', 0.07657657657657657)
# Coherencia -2.621025701489073
# Diversidad 0.46285714285714286
# 0 operacion, pago, coercitivo, tarjeta, deuda, credito, importe, gasto, superintendencia, rectificacion
# 1 desistimiento, anticipado, segun, conciliacion, arribar, jefe, continuar, hoc, conciliatorio, iniciacion
# 2 conciliatorio, voluntad, laudo, manifestacion, culminar, supletoriamente, observar, incumpla, complementar, doscientos
# 3 cum, pago, numero, seleccionar, pagar, ingresar, cancelar, liquidacion, nacion, cuenta
# 4 regional, urb, adscrito, hoc, jefe, archivar, segun, denegar, sol, transaccion
# 5 firma, junin, digital, opcion, huancayo, psje, provincia, validez, eficacia, fijo
# 6 telf, fax, urb, jefe, considerativo, coercitivo, indicado, pago, pagar, jus
# 7 cuenta, ahorro, pago, operacion, coercitivo, importe, transferencia, debito, tasa, rendimiento
# 8 conclusion, anticipado, continuar, promover, solucion, entranase, suscitado, iniciacion, interes, incorporar
# 9 centro, celular, especialista, hoc, pago, denegar, coercitivo, segun, generacion, continuacion
# 10 operacion, adicional, archivo, autorizacion, archivar, alegar, acreditado, correcto, importe, detalle
# 11 lambayeque, regional, anexo, opcion, tel, sol, pago, descripcion, pese, importe
# 12 susceptible, conceder, indefension, deniegan, impugnado, paralicen, suspension, causen, inadmisibilidad, digitalmente
# 13 calle, esquina, whatsapp, anexo, celular, florian, regional, sol, documentacion, adscrito
# 14 cobro, pago, periodo, coercitivo, archivar, tarjeta, presidencia, saldo, uso, credito
# 15 extrajudicial, torrejon, anticipado, desistimiento, transaccion, segun, razon, exigir, presidencia, promover
# 16 hora, mensaje, metodo, whatsapp, comunicar, abusivo, envio, llamada, pago, enviar
# 17 opcion, anexo, fijo, pago, avenida, provincia, comunicar, imposicion, titularidad, coercitivo
# 18 finanzas, interamericano, acceder, beneficio, previamente, inciso, rectificar, embargo, impedir, aceptar
# 19 pago, cargo, operacion, coercitivo, indicado, tarjeta, ascendente, credito, expedito, transparencia
# 20 reclamo, respuesta, adecuado, demostrar, inadecuado, archivar, octavo, presidencia, modo, inadecuadamente
# 21 club, coco, urb, credito, celular, hoc, importe, archivar, mantener, deuda
# 22 seguro, atribuir, credito, contratacion, tarjeta, deuda, indebidamente, fraude, registrar, inciso
# 23 conciliatorio, celebrar, compania, seguro, reaseguro, pago, imposicion, celular, segun, gasto
# 24 equipo, fondo, celular, causa, negativo, clave, archivo, continuar, pese, conciliacion
# 25 subsanacion, linea, avenida, impedir, oportunamente, descripcion, documentacion, continuacion, continuar, pendiente
# 26 internacional, acceder, interesado, apruebar, interes, plano, aceptar, presuntamente, opcion, apersonado
# 27 robo, improcedencia, victima, operacion, yape, credito, detalle, sueldo, presidencia, aplicativo
# 28 tarjeta, seguimiento, monitoreo, enmendar, vicio, trascendente, pasivo, activar, alertar, inusual
# 29 compra, retiro, ahorro, cajero, importe, operacion, cuenta, debitado, detalle, yape
# 30 septiembre, reembolso, reconocimiento, archivar, inciso, tarjeta, exoneracion, trabajador, inadecuado, credito
# 31 improcedente, jiron, sueldo, ejercicio, denegar, calificar, opcion, efectuado, cuadro, dolar
# 32 pago, prestamo, personal, coercitivo, expedito, llamar, movil, banca, dato, riesgo
# 33 cuota, correo, electronico, archivar, pago, registrar, interes, automatico, beneficio, cajero
# 34 cancelar, ciento, liquidacion, consentir, espontaneo, calculo, integridad, superar, pago, otorgado
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# DIVERSIDAD
# ..................................................
# ('subconjunto', 'comisión_lim')
# ('columna', 'dictamen_dom')
# ('numero_topicos', 3)
# ('hiperparametros', '8')
# ('model_id', 'comisión_lim_dictamen_dom_K3_8')
# ('diversidad', 1.0)
# ('coherencia_umass', -1.4983533045402606)
# ('del_dominio', 7)
# ('palabras_unicas', 30)
# ('porc_del_dominio', 0.23333333333333334)
# Coherencia -1.4983533045402606
# Diversidad 1.0
# 0 num, fax, telf, operacion, coercitivo, cuenta, pago, cargo, importe, modificatoria
# 1 interes, anticipado, conclusion, promover, finalizar, desistimiento, continuar, suscitado, iniciacion, archivo
# 2 firma, digital, mgtr, organizacion, regional, celular, certificado, fijo, eficacia, validez
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# COHERENCIA_UMASS
# ..................................................
# ('subconjunto', 'orps')
# ('columna', 'dictamen')
# ('numero_topicos', 3)
# ('hiperparametros', '4')
# ('model_id', 'orps_dictamen_K3_4')
# ('diversidad', 0.5)
# ('coherencia_umass', -0.1773679515798284)
# ('del_dominio', 3)
# ('palabras_unicas', 22)
# ('porc_del_dominio', 0.13636363636363635)
# Coherencia -0.1773679515798284
# Diversidad 0.5
# 0 sumarisimo, quedar, anticipado, poner, emitir, regular, requerir, previsto, consentido, coactivo
# 1 costa, imponer, pago, habil, coercitivo, quedar, sancion, operacion, tributario, proveedor
# 2 pago, quedar, sumarisimo, haber, establecer, habil, costa, coactivo, operacion, cum
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# {'7': "{'n_hip': 7, 'init': 'nndsvda', 'random_state': 42, 'solver': 'cd', 'beta_loss': 'frobenius', 'alpha_W': 0.001, 'alpha_H': 0.001, 'shuffle': True, 'tol': 0.001}", '6': "{'n_hip': 6, 'init': 'nndsvda', 'random_state': 42, 'solver': 'mu', 'beta_loss': 'kullback-leibler', 'alpha_W': 0.0, 'alpha_H': 0.0, 'shuffle': True, 'tol': 0.001}", '3': "{'n_hip': 3, 'init': 'random', 'random_state': 42, 'solver': 'cd', 'beta_loss': 'frobenius', 'alpha_W': 0.001, 'alpha_H': 0.001, 'shuffle': True, 'tol': 0.001}", '2': "{'n_hip': 2, 'init': 'random', 'random_state': 42, 'solver': 'mu', 'beta_loss': 'kullback-leibler', 'alpha_W': 0.0, 'alpha_H': 0.0, 'shuffle': True, 'tol': 0.001}", '5': "{'n_hip': 5, 'init': 'nndsvda', 'random_state': 42, 'solver': 'cd', 'beta_loss': 'frobenius', 'alpha_W': 0.0, 'alpha_H': 0.0, 'shuffle': True, 'tol': 0.001}", '4': "{'n_hip': 4, 'init': 'random', 'random_state': 42, 'solver': 'mu', 'beta_loss': 'kullback-leibler', 'alpha_W': 0.001, 'alpha_H': 0.001, 'shuffle': True, 'tol': 0.001}", '1': "{'n_hip': 1, 'init': 'random', 'random_state': 42, 'solver': 'cd', 'beta_loss': 'frobenius', 'alpha_W': 0.0, 'alpha_H': 0.0, 'shuffle': True, 'tol': 0.001}", '8': "{'n_hip': 8, 'init': 'nndsvda', 'random_state': 42, 'solver': 'mu', 'beta_loss': 'frobenius', 'alpha_W': 0.001, 'alpha_H': 0.001, 'shuffle': True, 'tol': 0.001}"}
# ==================================================
# ==================================================
# PORC_DEL_DOMINIO
# ..................................................
# ('subconjunto', 'comisión_lim')
# ('columna', 'denuncia_dictamen_bert')
# ('numero_topicos', 3)
# ('hiperparametros', 0.05)
# ('model_id', 'comisión_lim_denuncia_dictamen_bert_K3_0.05')
# ('diversidad', 0.26666666666666666)
# ('coherencia_umass', -0.30000496552890527)
# ('del_dominio', 2)
# ('palabras_unicas', 16)
# ('porc_del_dominio', 0.125)
# Coherencia -0.30000496552890527
# Diversidad 0.26666666666666666
# 0 el, protección, código, resolución, artículo, 2024, 18, perú, 29571, comisión
# 1 el, resolución, protección, perú, artículo, 2024, código, comisión, señor, cuenta
# 2 el, protección, artículo, ps0, perú, código, iln, resolución, tarjeta, crédito
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# DEL_DOMINIO
# ..................................................
# ('subconjunto', 'comisión_lim')
# ('columna', 'denuncia')
# ('numero_topicos', 41)
# ('hiperparametros', 0.01)
# ('model_id', 'comisión_lim_denuncia_K41_0.01')
# ('diversidad', 0.47804878048780486)
# ('coherencia_umass', -2.0924191753455323)
# ('del_dominio', 7)
# ('palabras_unicas', 241)
# ('porc_del_dominio', 0.029045643153526972)
# Coherencia -2.0924191753455323
# Diversidad 0.47804878048780486
# -1 el, protección, 2024, código, señor, infracción, habría, 29571, nº, seguro
# 0 ps2, el, señora, ops, resolución, 2024, cuenta, importe, protección, código
# 1 tarjeta, operaciones, el, cuenta, 00, crédito, señora, 2024, 17, código
# 2 el, artículo, resolución, jun, protección, señora, código, junín, aseguradora, iln
# 3 el, señor, 2024, orps, resolución, perú, nº, ps0, regional, oficina
# 4 el, señor, cuenta, 2024, préstamo, reclamo, perú, 2025, código, protección
# 5 iln, 2020, protección, el, artículo, infracción, av, habría, señor, código
# 6 iln, ps0, sancionador, importe, av, tarjeta, crédito, 988, 19, 2023
# 7 señor, domicilio, el, cobranza, cc1, 2023, st, tarjeta, protección, 2024
# 8 08, bill, apple, com, us, 18, 90, 29, 32, 70
# 9 el, cuenta, protección, cc1, sorteo, señor, operaciones, habría, nº, 2021
# 10 191, 074, operaciones, cuenta, señora, ahorros, 2023, 88, safet, el
# 11 ps2, débito, el, resolución, automático, perú, protección, reglamento, desafiliación, operaciones
# 12 conciliación, audiencia, solucionar, citó, llegó, conciliatorio, llevó, 2025, controversia, cabo
# 13 ps1, resolución, el, cc1, ops, seguido, ps2, ordenada, liquidación, apelación
# 14 señora, orps, cus, 2025, apelación, suma, el, hija, perú, 483
# 15 ps2, el, ops, iphone, operación, 2024, señor, resolución, 250, reglamento
# 16 spv, cesión, token, cartera, el, digital, regional, es, oficina, hipoteca
# 17 cláusula, línea, artículo, abusiva, porcentaje, incrementar, disminuir, suprimir, variar, crédito
# 18 envío, claves, 2023, mn, 222, operación, respuesta, 018, denunciada, el
# 19 ps2, resolución, el, ops, 2024, cumplimiento, reglamento, operación, allanamiento, septiembre
# 20 hipotecario, desgravamen, seguro, el, señor, bnp, protección, 0011, nº, cc1
# 21 097, premio, 193, 7637, 4547, tc33, 00, 09, digital, 11
# 22 lal, 215, cuentas, 2024, el, orps, 194, 2025, corrientes, resolución
# 23 iniciado, ps2, pretensión, ops, 2025, señor, resolvió, interpuso, desistimiento, el
# 24 cheques, 124, cc1, protección, 104, central, 9866, 502, fax, 41
# 25 señora, 5254, orps, 229, piu, presentado, 290, 2024, pagos, 880
# 26 desistimiento, iniciado, señora, formuló, pretensión, interpuso, 2025, 29571, banco1, 20251
# 27 señora, tarjeta, iln, extremo, operación, necesarias, av, el, crédito, evitar
# 28 operaciones, resolutivo, órgano, junín, el, 10, apercibimiento, perú, deberá, resolución
# 29 diners, special, edition, dc, 5426, tarjeta, cas, 131, crédito, l9s1b6
# 30 tarjeta, 7785, 4772, cargo, operaciones, 8535, reconocidas, importe, detalle, 2491
# 31 lal, transportes, skip, libertad, 2024, pago, el, santo, 518, recurrente
# 32 préstamo, el, habría, reclamo, anexo, perjuicio, opción, protección, sac, caso
# 33 interés, millonaria, 2024, usd, 315, tasa, automática, denunciado, renovación, mínima
# 34 operaciones, el, fallecimiento, titular, 01, ha, 2024, lt, denunciado, cuenta
# 35 markagroup, lam, pagaré, gerente, bnf, orps, acuerdos, denunciado, contrato, adoptados
# 36 piu, denunciantes, señoras, ps0, resolución, impuesto, bancarización, 2022, honorarios, abogada
# 37 corriente, apertura, solicitud, sospechoso, cuenta, era, crediticio, deudor, moneda, visita
# 38 millas, puntos, acumulación, lifemiles, canje, convenio, ofrecía, 5388, vida, correo
# 39 piu, 416, 00, señora, inmediata, 03, 620, transf, centrales, riesgo
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# DIVERSIDAD
# ..................................................
# ('subconjunto', 'comisión_lim')
# ('columna', 'denuncia_bert')
# ('numero_topicos', 5)
# ('hiperparametros', 0.05)
# ('model_id', 'comisión_lim_denuncia_bert_K5_0.05')
# ('diversidad', 0.58)
# ('coherencia_umass', -0.7063281833496116)
# ('del_dominio', 2)
# ('palabras_unicas', 37)
# ('porc_del_dominio', 0.05405405405405406)
# Coherencia -0.7063281833496116
# Diversidad 0.58
# -1 conciliación, audiencia, 2025, solucionar, citó, llegó, llevó, conciliatorio, controversia, cabo
# 0 el, protección, 2024, código, señor, comisión, infracción, cc1, habría, nº
# 1 el, 2024, resolución, perú, protección, código, señor, cuenta, comisión, nº
# 2 el, 08, 18, us, com, bill, apple, señora, protección, 29
# 3 el, tarjeta, protección, código, iln, perú, crédito, ps0, 00, artículo
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# COHERENCIA_UMASS
# ..................................................
# ('subconjunto', 'orps_lim')
# ('columna', 'dictamen_bert')
# ('numero_topicos', 6)
# ('hiperparametros', 0.05)
# ('model_id', 'orps_lim_dictamen_bert_K6_0.05')
# ('diversidad', 0.21666666666666667)
# ('coherencia_umass', -0.13043081588147026)
# ('del_dominio', 1)
# ('palabras_unicas', 25)
# ('porc_del_dominio', 0.04)
# Coherencia -0.13043081588147026
# Diversidad 0.21666666666666667
# -1 pedido, denegar, 27444, lam, soles, días, lambayeque, legislativo, formulado, constitucional
# 0 el, protección, artículo, código, resolución, perú, pago, órgano, días, hábiles
# 1 el, protección, artículo, resolución, código, órgano, pago, sumarísimos, días, día
# 2 el, protección, artículo, código, órgano, acuerdo, resolución, sumarísimos, apelación, día
# 3 el, protección, artículo, sumarísimos, órgano, apelación, resolución, desistimiento, día, 32
# 4 el, protección, artículo, código, resolución, sumarísimos, órgano, perú, día, apelación
# ==================================================
# ==================================================
#
# ==================================================
# ==================================================
# {0.05: 'porc_docs_min:5.0%', 0.01: 'porc_docs_min:1.0%'}
